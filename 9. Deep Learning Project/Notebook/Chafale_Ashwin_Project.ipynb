# %% [markdown]
# # DSCI 552 - Final Project
#
# ### Name : Ashwin Chafale
# ### Github username : chafale
# ### USC-ID : 1990624801

# %% [markdown]
# # 1. Text-Classification

# %% [markdown]
# ## (a) Build a classifier to analyze the sentiment of movies reviews. We are provided with text data in two folders: one folder involves positive reviews, and one folder involves negative reviews.

# %%
import glob
import string
import numpy as np
import pandas as pd
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras.layers import LSTM
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
# Load positive sentiments
positive_files = {}
files = glob.glob("../Data/pos/*.txt")
files.sort()
file_count = 0
for file in files:
    f = open(file,'r')
    positive_files[file_count] = ["".join(f.readlines())]
    file_count += 1
df = pd.DataFrame(positive_files, index=[0])
positive_df = df.T
positive_df.rename(columns={0:"reviews"} ,inplace=True)
positive_df
# Out:
#                                                reviews
# 0    films adapted from comic books have had plenty...
# 1    every now and then a movie comes along from a ...
# 2    you've got mail works alot better than it dese...
# 3     " jaws " is a rare film that grabs your atten...
# 4    moviemaking is a lot like being the general ma...
# ..                                                 ...
# 995  wow ! what a movie . \nit's everything a movie...
# 996  richard gere can be a commanding actor , but h...
# 997  glory--starring matthew broderick , denzel was...
# 998  steven spielberg's second epic film on world w...
# 999  truman ( " true-man " ) burbank is the perfect...
#
# [1000 rows x 1 columns]

# %%
# Load negative sentiments
negative_files = {}
files = glob.glob("../Data/neg/*.txt")
files.sort()
file_count = 0
for file in files:
    f = open(file,'r')
    negative_files[file_count] = ["".join(f.readlines())]
    file_count += 1
df = pd.DataFrame(negative_files, index=[0])
negative_df = df.T
negative_df.rename(columns={0:"reviews"} ,inplace=True)
negative_df
# Out:
#                                                reviews
# 0    plot : two teen couples go to a church party ,...
# 1    the happy bastard's quick movie review \ndamn ...
# 2    it is movies like these that make a jaded movi...
# 3     " quest for camelot " is warner bros . ' firs...
# 4    synopsis : a mentally unstable man undergoing ...
# ..                                                 ...
# 995  if anything , " stigmata " should be taken as ...
# 996  john boorman's " zardoz " is a goofy cinematic...
# 997  the kids in the hall are an acquired taste . \...
# 998  there was a time when john carpenter was a gre...
# 999  two party guys bob their heads to haddaway's d...
#
# [1000 rows x 1 columns]

# %% [markdown]
# ## (b) Data Exploration and Pre-processing

# %% [markdown]
# ### 1 (b) i. Use binary encoding for the sentiments , i.e y = 1 for positive sentiments and y = − 1 for negative sentiments.
#
# As per the question sentiments have to be [1, -1] but since the output layer of Neural Network is sigmoid we will assume
# sentiments to be [1, 0] where 1 represent positive review and 0 represent negative review respectively.
#
# The above assumption is for assignment simplicity.

# %%
positive_df['sentiments'] = [1] * len(positive_df)
negative_df['sentiments'] = [0] * len(negative_df) # make it -1

# %% [markdown]
# ### 1 (b) ii. Remove the punctuation and numbers from the data.
#
# Here in data preprocessing step english "stopword" are not been removed as I have observed that when stopwords are not removed our NN model accuracy increases.
#
# This behaviour is due to "not", "much" ... etc are considered stopword in nltk.corpus and few such stopwords might be useful for our model.
#
# So I am not eliminating english stopwords.

# %%
# from nltk.corpus import stopwords
def generateTokens(dataFrame):
    token_list = []
    for fileData in dataFrame['reviews']:

        # split into tokens by white space
        _tokens = fileData.split()

        # remove punctuation from each token
        table = str.maketrans('', '', string.punctuation)
        _tokens = [w.translate(table) for w in _tokens]

        # remove remaining tokens that are not alphabetic
        _tokens = [word for word in _tokens if word.isalpha()]

        # # filter out stop words
        # stop_words = set(stopwords.words('english'))
        # _tokens = [w for w in _tokens if not w in stop_words]

        # filter out short tokens
        _tokens = [word for word in _tokens if len(word) > 2]

        token_list.append(_tokens)

    return token_list

# %%
def dataPreprocessing(dataFrame):
    cleaned_data_list = []

    for fileData in dataFrame['tokens']:
        cleaned_data = " ".join(fileData)
        cleaned_data_list.append(cleaned_data)

    return cleaned_data_list

# %%
positive_df['sentiments'] = [1] * len(positive_df)
negative_df['sentiments'] = [0] * len(negative_df) # make it -1

# %% [markdown]
# ### 1 (b) iii. Use text files 0-699 in each class for training and 700-999 for testing.

# %%
positive_train, negative_train = positive_df[:700], negative_df[:700]
positive_test, negative_test = positive_df[700:], negative_df[700:]

# %%
p_list = generateTokens(positive_df)
n_list = generateTokens(negative_df)
p_train, n_train = p_list[:700], n_list[:700]
p_test, n_test = p_list[700:], n_list[700:]

# %%
X_train = p_train + n_train
X_test = p_test + n_test
y_train = pd.concat([positive_train.iloc[:,1], negative_train.iloc[:,1]], ignore_index=True)
y_test = pd.concat([positive_test.iloc[:,1], negative_test.iloc[:,1]], ignore_index=True)

# %% [markdown]
# ### 1 (b) iv. Count the number of unique words in the whole dataset (train + test) and print it out.

# %%
from collections import Counter

completeDataset = p_list + n_list

uniqueWords = Counter()
for strList in completeDataset:
    uniqueWords.update(strList)
uniqueWords
# Out:
# Counter({'films': 2102,
#          'adapted': 45,
#          'from': 4986,
#          'comic': 375,
#          'books': 81,
#          'have': 4899,
#          'had': 1544,
#          'plenty': 129,
#          'success': 216,
#          'whether': 216,
#          'theyre': 414,
#          'about': 3518,
#          'superheroes': 12,
#          'batman': 195,
#          'superman': 23,
#          'spawn': 75,
#          'geared': 13,
#          'toward': 100,
#          'kids': 339,
#          'casper': 22,
#          'the': 76324,
#          'arthouse': 7,
#          'crowd': 74,
#          'ghost': 74,
#          'world': 963,
#          'but': 8584,
#          'theres': 993,
#          'never': 1364,
#          'really': 1563,
#          'been': 2045,
#          'book': 330,
#          'like': 3553,
#          'hell': 261,
#          'before': 987,
#          'for': 9914,
#          'starters': 8,
#          'was': 4934,
#          'created': 162,
#          'alan': 99,
#          'moore': 73,
#          'and': 35351,
#          'eddie': 143,
#          'campbell': 88,
#          'who': 5378,
#          'brought': 157,
#          'medium': 29,
#          'whole': 495,
#          'new': 1277,
#          'level': 243,
#          'mid': 13,
#          'with': 10779,
#          'series': 537,
#          'called': 356,
#          'watchmen': 1,
#          'say': 802,
#          'thoroughly': 70,
#          'researched': 1,
#          'subject': 163,
#          'jack': 269,
#          'ripper': 5,
#          'would': 2042,
#          'saying': 170,
#          'michael': 411,
#          'jackson': 108,
#          'starting': 60,
#          'look': 829,
#          'little': 1491,
#          'odd': 108,
#          'graphic': 86,
#          'novel': 254,
#          'you': 4437,
#          'will': 2194,
#          'over': 1300,
#          'pages': 22,
#          'long': 751,
#          'includes': 108,
#          'nearly': 303,
#          'more': 3345,
#          'that': 15111,
#          'consist': 9,
#          'nothing': 800,
#          'footnotes': 2,
#          'other': 1925,
#          'words': 214,
#          'dont': 1210,
#          'dismiss': 14,
#          'this': 9565,
#          'film': 8860,
#          'because': 1682,
#          'its': 5984,
#          'source': 61,
#          'can': 2232,
#          'get': 1921,
#          'past': 333,
#          'thing': 802,
#          'might': 624,
#          'find': 779,
#          'another': 1111,
#          'stumbling': 15,
#          'block': 44,
#          'hells': 6,
#          'directors': 157,
#          'albert': 43,
#          'allen': 131,
#          'hughes': 48,
#          'getting': 404,
#          'brothers': 218,
#          'direct': 67,
#          'seems': 1032,
#          'almost': 811,
#          'ludicrous': 41,
#          'casting': 125,
#          'carrot': 11,
#          'top': 286,
#          'well': 1694,
#          'anything': 618,
#          'riddle': 1,
#          'better': 914,
#          'thats': 788,
#          'set': 545,
#          'ghetto': 24,
#          'features': 216,
#          'violent': 135,
#          'street': 129,
#          'crime': 199,
#          'than': 2438,
#          'mad': 82,
#          'geniuses': 12,
#          'behind': 351,
#          'menace': 105,
#          'society': 149,
#          'question': 277,
#          'course': 647,
#          'whitechapel': 2,
#          'londons': 4,
#          'east': 36,
#          'end': 1047,
#          'filthy': 5,
#          'sooty': 1,
#          'place': 610,
#          'where': 1459,
#          'whores': 2,
#          'unfortunates': 2,
#          'are': 6945,
#          'nervous': 37,
#          'mysterious': 118,
#          'psychopath': 14,
#          'has': 4715,
#          'carving': 5,
#          'through': 1180,
#          'their': 3116,
#          'profession': 33,
#          'surgical': 2,
#          'precision': 11,
#          'when': 3254,
#          'first': 1768,
#          'stiff': 22,
#          'turns': 402,
#          'copper': 5,
#          'peter': 253,
#          'godley': 1,
#          'robbie': 30,
#          'coltrane': 5,
#          'not': 5527,
#          'enough': 907,
#          'calls': 100,
#          'inspector': 39,
#          'frederick': 7,
#          'abberline': 2,
#          'johnny': 74,
#          'depp': 43,
#          'blow': 51,
#          'crack': 37,
#          'case': 419,
#          'widower': 7,
#          'prophetic': 5,
#          'dreams': 128,
#          'unsuccessfully': 9,
#          'tries': 369,
#          'quell': 3,
#          'copious': 6,
#          'amounts': 33,
#          'absinthe': 2,
#          'opium': 2,
#          'upon': 305,
#          'arriving': 17,
#          'befriends': 28,
#          'unfortunate': 60,
#          'named': 353,
#          'mary': 133,
#          'kelly': 86,
#          'heather': 31,
#          'graham': 44,
#          'isnt': 870,
#          'proceeds': 29,
#          'investigate': 50,
#          'horribly': 43,
#          'gruesome': 24,
#          'crimes': 31,
#          'even': 2555,
#          'police': 239,
#          'surgeon': 11,
#          'cant': 645,
#          'stomach': 23,
#          'think': 842,
#          'anyone': 411,
#          'needs': 221,
#          'briefed': 1,
#          'wont': 260,
#          'into': 2617,
#          'particulars': 6,
#          'here': 1108,
#          'unique': 115,
#          'interesting': 633,
#          'theory': 48,
#          'both': 892,
#          'identity': 79,
#          'killer': 260,
#          'reasons': 131,
#          'chooses': 37,
#          'slay': 2,
#          'they': 4278,
#          'bother': 49,
#          'cloaking': 1,
#          'screenwriters': 69,
#          'terry': 54,
#          'hayes': 7,
#          'vertical': 6,
#          'limit': 10,
#          'rafael': 6,
#          'yglesias': 3,
#          'les': 27,
#          'mis': 3,
#          'rables': 2,
#          'good': 2320,
#          'job': 550,
#          'keeping': 87,
#          'him': 2631,
#          'hidden': 77,
#          'viewers': 187,
#          'until': 430,
#          'very': 1863,
#          'funny': 829,
#          'watch': 601,
#          'locals': 16,
#          'blindly': 5,
#          'point': 670,
#          'finger': 23,
#          'blame': 87,
#          'jews': 24,
#          'indians': 13,
#          'after': 1754,
#          'all': 4251,
#          'englishman': 4,
#          'could': 1395,
#          'capable': 68,
#          'committing': 13,
#          'such': 1217,
#          'ghastly': 9,
#          'acts': 73,
#          'ending': 421,
#          'whistling': 1,
#          'stonecutters': 1,
#          'song': 129,
#          'simpsons': 12,
#          'days': 341,
#          'holds': 84,
#          'back': 1034,
#          'electric': 15,
#          'carwho': 1,
#          'made': 1026,
#          'steve': 151,
#          'guttenberg': 4,
#          'star': 677,
#          'worry': 35,
#          'itll': 26,
#          'make': 1590,
#          'sense': 553,
#          'see': 1730,
#          'now': 977,
#          'onto': 119,
#          'appearance': 125,
#          'certainly': 360,
#          'dark': 309,
#          'bleak': 50,
#          'surprising': 100,
#          'how': 1509,
#          'much': 2024,
#          'looks': 444,
#          'tim': 155,
#          'burton': 58,
#          'planet': 236,
#          'apes': 87,
#          'did': 763,
#          'times': 566,
#          'sleepy': 40,
#          'hollow': 70,
#          'print': 27,
#          'saw': 252,
#          'wasnt': 290,
#          'completely': 439,
#          'finished': 35,
#          'color': 86,
#          'music': 475,
#          'finalized': 2,
#          'comments': 53,
#          'marilyn': 14,
#          'manson': 9,
#          'cinematographer': 66,
#          'deming': 1,
#          'word': 214,
#          'ably': 11,
#          'captures': 38,
#          'dreariness': 2,
#          'victorianera': 1,
#          'london': 61,
#          'helped': 54,
#          'flashy': 39,
#          'killing': 137,
#          'scenes': 1265,
#          'remind': 31,
#          'crazy': 84,
#          'flashbacks': 69,
#          'twin': 41,
#          'peaks': 17,
#          'though': 936,
#          'violence': 298,
#          'pales': 5,
#          'comparison': 72,
#          'blackandwhite': 12,
#          'oscar': 210,
#          'winner': 70,
#          'martin': 164,
#          'childs': 25,
#          'shakespeare': 70,
#          'love': 1089,
#          'production': 290,
#          'design': 87,
#          'original': 704,
#          'prague': 1,
#          'surroundings': 17,
#          'one': 5521,
#          'creepy': 92,
#          'acting': 689,
#          'solid': 171,
#          'dreamy': 9,
#          'turning': 79,
#          'typically': 27,
#          'strong': 259,
#          'performance': 885,
#          'deftly': 7,
#          'handling': 24,
#          'british': 141,
#          'accent': 95,
#          'ians': 1,
#          'holm': 17,
#          'joe': 287,
#          'goulds': 3,
#          'secret': 175,
#          'richardson': 26,
#          'dalmatians': 20,
#          'log': 4,
#          'great': 1141,
#          'supporting': 275,
#          'roles': 281,
#          'big': 970,
#          'surprise': 210,
#          'cringed': 3,
#          'time': 2283,
#          'she': 2687,
#          'opened': 40,
#          'her': 4504,
#          'mouth': 90,
#          'imagining': 5,
#          'attempt': 260,
#          'irish': 44,
#          'actually': 834,
#          'half': 393,
#          'bad': 1374,
#          'however': 986,
#          'violencegore': 3,
#          'sexuality': 35,
#          'language': 123,
#          'drug': 147,
#          'content': 77,
#          'every': 945,
#          'then': 1407,
#          'movie': 5440,
#          'comes': 733,
#          'along': 529,
#          'suspect': 87,
#          'studio': 149,
#          'indication': 11,
#          'stinker': 8,
#          'everybodys': 8,
#          'perhaps': 458,
#          'becomes': 526,
#          'critical': 58,
#          'darling': 4,
#          'mtv': 41,
#          'election': 34,
#          'high': 498,
#          'school': 375,
#          'comedy': 800,
#          'starring': 178,
#          'matthew': 113,
#          'broderick': 51,
#          'reese': 45,
#          'witherspoon': 30,
#          'current': 77,
#          'example': 299,
#          'anybody': 39,
#          'know': 1207,
#          'existed': 9,
#          'week': 78,
#          'plot': 1451,
#          'deceptively': 5,
#          'simple': 281,
#          'george': 223,
#          'washington': 71,
#          'carver': 18,
#          'having': 548,
#          'student': 108,
#          'elections': 5,
#          'tracy': 21,
#          'flick': 192,
#          'overachiever': 2,
#          'hand': 332,
#          'raised': 46,
#          'way': 1668,
#          'sick': 75,
#          'megalomaniac': 6,
#          'encourages': 7,
#          'paul': 226,
#          'popularbutslow': 1,
#          'jock': 18,
#          'run': 323,
#          'pauls': 12,
#          'nihilistic': 8,
#          'sister': 130,
#          'jumps': 41,
#          'race': 118,
#          'personal': 189,
#          'side': 317,
#          'sleeper': 14,
#          'expectations': 88,
#          'were': 1458,
#          'low': 111,
#          'going': 871,
#          'fact': 795,
#          'quality': 192,
#          'stuff': 206,
#          'reviews': 92,
#          'enthusiastic': 18,
#          'any': 1573,
#          'right': 782,
#          'help': 532,
#          'baggage': 12,
#          'glowing': 17,
#          'which': 3155,
#          'contrast': 65,
#          'negative': 43,
#          'reviewers': 22,
#          'likely': 164,
#          'does': 1570,
#          'live': 322,
#          'hype': 53,
#          'what': 3078,
#          'makes': 992,
#          'disappointing': 87,
#          'contains': 117,
#          'significant': 58,
#          'details': 118,
#          'lifted': 26,
#          'directly': 74,
#          'rushmore': 22,
#          'released': 206,
#          'few': 964,
#          'months': 111,
#          'earlier': 148,
#          'similarities': 26,
#          'staggering': 12,
#          'president': 107,
#          'extraordinary': 56,
#          'number': 220,
#          'clubs': 22,
#          'involved': 241,
#          'play': 445,
#          'max': 128,
#          'fischer': 8,
#          'most': 2300,
#          'tension': 136,
#          'potential': 169,
#          'relationship': 359,
#          'between': 954,
#          'teacher': 106,
#          'his': 9569,
#          'single': 218,
#          'parent': 29,
#          'home': 544,
#          'contributed': 13,
#          'drive': 95,
#          'male': 102,
#          'bumbling': 32,
#          'adult': 106,
#          'pursues': 11,
#          'extramarital': 4,
#          'affair': 95,
#          'gets': 864,
#          'caught': 122,
#          'life': 1472,
#          'ruined': 34,
#          'bee': 9,
#          'sting': 9,
#          'bill': 172,
#          'murray': 54,
#          'several': 417,
#          'stings': 2,
#          'happened': 163,
#          'individual': 75,
#          'screenplay': 286,
#          'contain': 42,
#          'many': 1268,
#          'points': 160,
#          'yet': 600,
#          'probably': 538,
#          'aware': 60,
#          'each': 682,
#          'two': 1825,
#          'different': 429,
#          'studios': 60,
#          'genre': 249,
#          'geeks': 5,
#          'revenge': 90,
#          'hadnt': 38,
#          'fully': 90,
#          'formed': 15,
#          'strengths': 16,
#          'rely': 34,
#          'fantastic': 78,
#          'performances': 430,
#          'newcomer': 31,
#          'jessica': 36,
#          'antisocial': 6,
#          'tammy': 5,
#          'playing': 351,
#          'rooney': 3,
#          'role': 863,
#          'ferris': 15,
#          'bueller': 2,
#          'fun': 571,
#          'hes': 1150,
#          'since': 768,
#          'revelation': 37,
#          'early': 295,
#          'year': 594,
#          'teenagers': 85,
#          'clout': 9,
#          'money': 501,
#          'deserves': 111,
#          'nomination': 60,
#          'once': 601,
#          'campbells': 6,
#          'character': 1906,
#          'speech': 92,
#          'gymnasium': 2,
#          'youre': 332,
#          'won': 73,
#          'bothering': 7,
#          'ive': 381,
#          'seen': 902,
#          'there': 2758,
#          'amount': 132,
#          'suppose': 92,
#          'coming': 261,
#          'should': 864,
#          'expect': 215,
#          'less': 452,
#          'starts': 316,
#          'off': 1422,
#          'light': 185,
#          'airy': 6,
#          'sitcom': 52,
#          'screws': 12,
#          'tighten': 2,
#          'tensions': 9,
#          'mount': 7,
#          'alexander': 26,
#          'payne': 12,
#          'decides': 188,
#          'add': 176,
#          'elements': 236,
#          'frankly': 55,
#          'distract': 18,
#          'story': 2118,
#          'doesnt': 1267,
#          'tracys': 2,
#          'determination': 16,
#          'win': 109,
#          'costs': 23,
#          'throw': 97,
#          'studentteacher': 1,
#          'logical': 26,
#          'reason': 435,
#          'why': 878,
#          'lot': 675,
#          'tonal': 1,
#          'nosedive': 3,
#          'takes': 668,
#          'explicitly': 11,
#          'sexdriven': 2,
#          'mark': 163,
#          'disappointment': 67,
#          'youve': 188,
#          'got': 470,
#          'mail': 32,
#          'works': 359,
#          'alot': 8,
#          'order': 282,
#          'cast': 760,
#          'extremely': 248,
#          'popular': 191,
#          'attractive': 81,
#          'stars': 383,
#          'them': 1877,
#          'share': 112,
#          'screen': 626,
#          'hours': 239,
#          'collect': 19,
#          'profits': 6,
#          'real': 858,
#          'inventive': 51,
#          'bone': 48,
#          'body': 258,
#          'basically': 210,
#          'complete': 197,
#          'reshoot': 5,
#          'shop': 55,
#          'around': 896,
#          'corner': 52,
#          'only': 2483,
#          'adding': 36,
#          'modern': 134,
#          'twists': 114,
#          'essentially': 62,
#          'goes': 646,
#          'against': 366,
#          'defies': 15,
#          'concepts': 23,
#          'contemporary': 50,
#          'filmmaking': 110,
#          'overly': 65,
#          'sentimental': 39,
#          'terribly': 56,
#          'mushy': 4,
#          'mention': 113,
#          'manipulative': 38,
#          'enjoyable': 163,
#          'manipulation': 17,
#          'must': 606,
#          'something': 1048,
#          'work': 1007,
#          'absolutely': 186,
#          'hated': 35,
#          'previous': 186,
#          'ryanhanks': 1,
#          'teaming': 8,
#          'sleepless': 11,
#          'seattle': 23,
#          'couldnt': 185,
#          'directing': 117,
#          'helmed': 15,
#          'same': 869,
#          'woman': 515,
#          'havent': 147,
#          'quite': 657,
#          'figured': 29,
#          'out': 3441,
#          'liked': 154,
#          'again': 681,
#          'important': 208,
#          'storyline': 115,
#          'cliched': 67,
#          'come': 772,
#          'tom': 259,
#          'hanks': 91,
#          'plays': 753,
#          'fox': 102,
#          'insanely': 12,
#          'likeable': 47,
#          'owner': 88,
#          'discount': 9,
#          'chain': 43,
#          'meg': 56,
#          'ryan': 201,
#          'kathleen': 26,
#          'kelley': 17,
#          'proprietor': 6,
#          'familyrun': 1,
#          'childrens': 52,
#          'nice': 336,
#          'homage': 50,
#          'soon': 382,
#          'become': 509,
#          'bitter': 58,
#          'rivals': 13,
#          'store': 118,
#          'opening': 301,
#          'across': 219,
#          'small': 406,
#          'business': 186,
#          'already': 285,
#          'internet': 38,
#          'neither': 158,
#          'party': 176,
#          'knows': 278,
#          'persons': 28,
#          'true': 388,
#          'rest': 431,
#          'serve': 79,
#          'mere': 47,
#          'backdrop': 31,
#          'sure': 518,
#          'some': 2981,
#          'mildly': 43,
#          'subplots': 66,
#          'fail': 69,
#          'utter': 41,
#          'cuteness': 10,
#          'main': 399,
#          'leads': 231,
#          'predictable': 180,
#          'climax': 121,
#          'foreseeable': 2,
#          'damn': 87,
#          'cute': 125,
#          'welldone': 10,
#          'doubt': 172,
#          'entire': 406,
#          'scene': 1373,
#          'evokes': 10,
#          'pure': 90,
#          'joy': 60,
#          'part': 703,
#          'discovers': 112,
#          'online': 14,
#          'filled': 161,
#          'lack': 235,
#          'happiness': 39,
#          'left': 412,
#          'theater': 227,
#          'smiling': 14,
#          'jaws': 37,
#          'rare': 95,
#          'grabs': 14,
#          'your': 843,
#          'attention': 238,
#          'shows': 432,
#          'image': 110,
#          'opens': 175,
#          'blackness': 4,
#          'distant': 35,
#          'alienlike': 1,
#          'underwater': 26,
#          'sounds': 133,
#          'ominous': 27,
#          'bars': 18,
#          'composer': 17,
#          'john': 774,
#          'williams': 217,
#          'infamous': 43,
#          'score': 210,
#          'dahdum': 1,
#          'director': 1056,
#          'steven': 134,
#          'spielberg': 90,
#          'wastes': 12,
#          'taking': 238,
#          'water': 171,
#          'midnight': 50,
#          'swim': 12,
#          'beautiful': 294,
#          'girl': 404,
#          'deadly': 58,
#          'away': 650,
#          'lets': 198,
#          'vulnerable': 28,
#          'floating': 37,
#          'ocean': 59,
#          'attacked': 28,
#          'relinquishes': 1,
#          'grip': 19,
#          'outstanding': 74,
#          'builds': 36,
#          'theatrical': 61,
#          'act': 277,
#          'second': 361,
#          'unlike': 167,
#          'filmmakers': 208,
#          'deal': 218,
#          'restraint': 25,
#          'refuses': 58,
#          'show': 700,
#          'shark': 34,
#          'middle': 197,
#          'merely': 160,
#          'suggests': 50,
#          'presence': 192,
#          'subjective': 10,
#          'shots': 186,
#          'building': 111,
#          'bit': 564,
#          'sharks': 11,
#          'arrival': 37,
#          'truly': 274,
#          'terrifying': 41,
#          'let': 288,
#          'bored': 82,
#          'imagery': 41,
#          'chief': 67,
#          'brody': 14,
#          'roy': 21,
#          'scheider': 4,
#          'york': 257,
#          'cop': 173,
#          'taken': 225,
#          'easy': 216,
#          'peaceful': 22,
#          'running': 313,
#          'station': 86,
#          'amity': 1,
#          'island': 130,
#          'fictitious': 9,
#          'england': 57,
#          'resort': 19,
#          'town': 374,
#          'hasnt': 97,
#          'murder': 246,
#          'gun': 144,
#          'fired': 33,
#          'years': 968,
#          'shaken': 9,
#          'vicious': 41,
#          'white': 274,
#          'attacks': 60,
#          'fourth': 38,
#          'july': 19,
#          'mayor': 29,
#          'larry': 82,
#          'vaughn': 18,
#          'hamilton': 8,
#          'want': 557,
#          'shut': 43,
#          'down': 874,
#          'beaches': 1,
#          'reliant': 4,
#          'summer': 313,
#          'tourist': 12,
#          'joined': 26,
#          'matt': 92,
#          'hooper': 4,
#          'richard': 157,
#          'dreyfuss': 26,
#          'young': 738,
#          'ambitious': 39,
#          'expert': 45,
#          'marine': 17,
#          'institute': 8,
#          'fascinated': 22,
#          'determined': 78,
#          'stop': 244,
#          'knowledge': 69,
#          'exact': 64,
#          'workings': 7,
#          'perfect': 334,
#          'engine': 11,
#          'eating': 44,
#          'machine': 103,
#          'finally': 350,
#          'relents': 1,
#          'join': 83,
#          'crusty': 4,
#          'old': 728,
#          'quint': 3,
#          'robert': 288,
#          'shaw': 31,
#          'decrepit': 4,
#          'boat': 77,
#          'orca': 3,
#          'search': 113,
#          'three': 628,
#          'men': 516,
#          'hunt': 75,
#          'inevitably': 35,
#          'hunted': 11,
#          'thriller': 241,
#          'keen': 15,
#          'humor': 405,
#          'incredible': 95,
#          'pacing': 68,
#          'horror': 433,
#          'ten': 153,
#          'movies': 1416,
#          'rolled': 18,
#          'wonder': 246,
#          'took': 164,
#          'america': 169,
#          'storm': 60,
#          'crown': 15,
#          'box': 143,
#          'office': 175,
#          'champ': 6,
#          'unceremoniously': 5,
#          'dethroned': 1,
#          'wars': 180,
#          'today': 107,
#          'fascination': 18,
#          'par': 37,
#          'hitchcocks': 16,
#          'psycho': 52,
#          'age': 172,
#          'although': 795,
#          'grand': 82,
#          'technology': 77,
#          'exists': 44,
#          'technical': 94,
#          'sequences': 291,
#          'including': 330,
#          'mechanical': 24,
#          'obsolete': 5,
#          'none': 233,
#          'improve': 17,
#          'lead': 248,
#          'overkill': 11,
#          'limitations': 8,
#          'faced': 42,
#          'may': 854,
#          'produced': 116,
#          'forced': 217,
#          'traditional': 61,
#          'cinematic': 133,
#          'characterization': 71,
#          'sharp': 64,
#          'editing': 100,
#          'creative': 70,
#          'photography': 56,
#          'instead': 565,
#          'simply': 428,
#          'dousing': 3,
#          'audience': 878,
#          'digital': 52,
#          'effects': 629,
#          'known': 266,
#          'actors': 716,
#          'draw': 68,
#          'redford': 22,
#          'newman': 30,
#          'nevertheless': 59,
#          'guaranteed': 19,
#          'successful': 182,
#          'careers': 27,
#          'gave': 141,
#          'refused': 14,
#          'overshadowed': 16,
#          'hits': 91,
#          'just': 2900,
#          'notes': 53,
#          'sympathetic': 82,
#          'husband': 224,
#          'father': 422,
#          'political': 154,
#          'quagmire': 2,
#          'doing': 343,
#          'whats': 234,
#          'warns': 21,
#          'previously': 67,
#          'american': 515,
#          'graffiti': 4,
#          'apprenticeship': 1,
#          'duddy': 1,
#          'kravitz': 1,
#          'gives': 507,
#          'surprisingly': 189,
#          'mature': 48,
#          'complex': 135,
#          'someone': 375,
#          'literally': 104,
#          'played': 788,
#          'gnarled': 2,
#          'captain': 96,
#          'ahab': 1,
#          'sorely': 13,
#          'overlooked': 19,
#          'academy': 92,
#          'awards': 41,
#          'bordering': 6,
#          'parody': 79,
#          'grizzled': 3,
#          'loner': 7,
#          'whose': 434,
#          ...})

# %%
len(uniqueWords)
# Out:
# 46473

# %% [markdown]
# ### 1 (b) v. Calculate the average review length and the standard deviation of review lengths. Report the results.

# %%
# Summarize review length
X = p_list + n_list
print("Review length summary : ")
result = [len(x) for x in X]
print("Average review length = ", np.mean(result))
print("Standard deviation of review length = ", np.std(result))
print("Maximum review length", np.max(result))
# Out:
# Review length summary :
# Average review length =  518.621
# Standard deviation of review length =  228.57963242380106
# Maximum review length 1875

# %% [markdown]
# ### 1 (b) vi. Plot the histogram of review lengths.

# %%
import matplotlib.pyplot as plt
n, bins, patches = plt.hist(x=result, bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Review Length')
plt.ylabel('Frequency')
plt.plot()
# Out:
# []

# %% [markdown]
# ### 1 (b) viii. Select a review length L that 70% of the reviews have a length below it.
#
# From the review length summary and histogram, we will choose L = 750 which corresponds to 70% of the reviews that have a length below it.

# %%
L = 750

# %% [markdown]
# ### 1 (b) vii. Tokenization
# The most common word in the text will be represented as 1, the second most common word will be represented as 2, etc. We will tokenize each text document using this method.

# %%
# create the tokenizer
tokenizer = Tokenizer()

# fit the tokenizer on the documents
tokenizer.fit_on_texts(X_train)

# %% [markdown]
# ### 1 (b) ix. Truncate reviews longer than L words and zero-pad reviews shorter than L so that all texts are of length L

# %%
# sequence encode
encoded_docs = tokenizer.texts_to_sequences(X_train)

# pad sequences
max_length = L # from section 1 (b) vii
print(max_length)

Xtrain = pad_sequences(encoded_docs, maxlen=max_length, padding='post')
Xtrain
# Out:
# 750
# array([[   46,  3370,    17, ...,     0,     0,     0],
#        [  123,   115,     2, ...,     0,     0,     0],
#        [  682,   260,  4108, ...,     0,     0,     0],
#        ...,
#        [ 5796,   630,   570, ...,     0,     0,     0],
#        [   62,  1657, 22628, ...,     0,     0,     0],
#        [ 1062,    33,    96, ...,     0,     0,     0]], dtype=int32)

# %%
# sequence encode
encoded_docs = tokenizer.texts_to_sequences(X_test)

# pad sequences
Xtest = pad_sequences(encoded_docs, maxlen=max_length, padding='post')
Xtest
# Out:
# array([[  472,   251, 11299, ...,  1421,  1022,   549],
#        [  631, 10182,   928, ...,    35,   938,  1847],
#        [    1,    53,  6680, ...,     0,     0,     0],
#        ...,
#        [    1,   363,     1, ...,     0,     0,     0],
#        [   34,    16,    42, ...,     0,     0,     0],
#        [   59,   841,   431, ...,     0,     0,     0]], dtype=int32)

# %% [markdown]
# ## 1 (c) Word Embeddings

# %% [markdown]
# ### 1 (c) i. Tokenized the input text using "Word Embedding"

# %%
# define vocabulary size (largest integer value)
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 39290

# %%
embedding_layer = Embedding(vocab_size, 32, input_length=max_length)

# %% [markdown]
# ### 1 (c) ii. Flatten the matrix of each document to a vector
#
# We can achieve this by using `keras.layers.Flatten`.
# Flattening of matrix is done in below code. Please refer 1 (d), 1(e), 1(f).

# %% [markdown]
# ## 1 (d) Multi-Layer Perceptron
#
# ##### 1 (d) i. Train a MLP with three (dense) hidden layers each of which has 50 ReLUs and one output layer with a single sigmoid neuron. Use a dropout rate of 20% for the first layer and 50% for the other layers. Use ADAM optimizer and binary cross entropy loss (which is equivalent to having a softmax in the output). To avoid overfitting, just set the number of epochs as 2. Use a batch size of 10.

# %%
from keras.layers import Dropout
model = Sequential()
model.add(Embedding(vocab_size, 32, input_length=max_length))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 750, 32)           1257280
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 24000)             0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24000)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                1200050
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 2,462,481
# Trainable params: 2,462,481
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### 1 (d) ii. Report the train and test accuracies of this model.

# %%
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, y_train, batch_size= 10, epochs=2)
# Out:
# Epoch 1/2
# 140/140 [==============================] - 3s 17ms/step - loss: 0.6688 - accuracy: 0.5914
# Epoch 2/2
# 140/140 [==============================] - 2s 18ms/step - loss: 0.4681 - accuracy: 0.7814
# <keras.callbacks.History at 0x7f75ce351a60>

# %%
# evaluate
_, acc = model.evaluate(Xtest, y_test, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 60.333333

# %% [markdown]
# #### Observation :
# If we increase the number of epoch the test accuracy increases.
# Here in below code we will run MLP for 10 epoch.

# %%
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, y_train, batch_size= 10 ,epochs=10)
# Out:
# Epoch 1/10
# 1400/1400 [==============================] - 6s 4ms/step - loss: 0.6978 - accuracy: 0.4971
# Epoch 2/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.6882 - accuracy: 0.5550
# Epoch 3/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.6144 - accuracy: 0.6793
# Epoch 4/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.2993 - accuracy: 0.8836
# Epoch 5/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0617 - accuracy: 0.9800
# Epoch 6/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0327 - accuracy: 0.9907
# Epoch 7/10
# 1400/1400 [==============================] - 6s 4ms/step - loss: 0.0185 - accuracy: 0.9950
# Epoch 8/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0135 - accuracy: 0.9971
# Epoch 9/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0125 - accuracy: 0.9943
# Epoch 10/10
# 1400/1400 [==============================] - 5s 4ms/step - loss: 0.0064 - accuracy: 0.9986

# %%
# evaluate
_, acc = model.evaluate(Xtest, y_test, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 66.666669

# %% [markdown]
# ## 1 (e) One-Dimensional Convolutional Neural Network:
#
# ###### 1 (e) i. After the embedding layer, insert a Conv1D layer. This convolutional layer has 32 feature maps , and each of the 32 kernels has size 3, i.e. reads embedded word representations 3 vector elements of the word embedding at a time. The convolutional layer is followed by a 1D max pooling layer with a length and stride of 2 that halves the size of the feature maps from the convolutional layer. The rest of the network is the same as the neural network above.

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32, input_length=max_length))
model.add(Conv1D(filters=32, kernel_size=32))
model.add(MaxPooling1D(strides=2))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(50, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 750, 32)           1257280
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 719, 32)           32800
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 359, 32)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 11488)             0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 11488)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                574450
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 1,869,681
# Trainable params: 1,869,681
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### 1 (e) ii. Report the train and test accuracies of this model.

# %%
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, y_train, batch_size= 10 ,epochs=2)
# Out:
# Epoch 1/2
# 140/140 [==============================] - 6s 37ms/step - loss: 0.6341 - accuracy: 0.6407
# Epoch 2/2
# 140/140 [==============================] - 5s 38ms/step - loss: 0.3357 - accuracy: 0.8714
# <keras.callbacks.History at 0x7fa56acb9fa0>

# %%
# evaluate
_, acc = model.evaluate(Xtest, y_test, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 80.833334

# %% [markdown]
# #### Observation :
# If we increase the number of epoch the test accuracy increases.
# Here in below code we will run 1D-CNN for 10 epoch.

# %%
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, y_train, batch_size= 10 ,epochs=10)
# Out:
# Epoch 1/10
# 1400/1400 [==============================] - 13s 9ms/step - loss: 0.7001 - accuracy: 0.5243
# Epoch 2/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.6911 - accuracy: 0.5379
# Epoch 3/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.6855 - accuracy: 0.5814
# Epoch 4/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.4559 - accuracy: 0.8050
# Epoch 5/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.1754 - accuracy: 0.9479
# Epoch 6/10
# 1400/1400 [==============================] - 15s 11ms/step - loss: 0.0487 - accuracy: 0.9886
# Epoch 7/10
# 1400/1400 [==============================] - 13s 9ms/step - loss: 0.0163 - accuracy: 0.9929
# Epoch 8/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.0194 - accuracy: 0.9950
# Epoch 9/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 10/10
# 1400/1400 [==============================] - 12s 9ms/step - loss: 0.0035 - accuracy: 0.9993

# %%
# evaluate
_, acc = model.evaluate(Xtest, y_test, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 83.833331

# %% [markdown]
# ## 1 (f) Long Short-Term Memory Recurrent Neural Network:
#
# ###### 1 (f) i. Each word is represented to LSTM as a vector of 32 elements and the LSTM is followed by a dense layer of 256 ReLUs. Use a dropout rate of 0.2 for both LSTM and the dense layer. Train the model using 10-50 epochs and batch size of 10.

# %%
from IPython.display import Image
Image(filename="img.png")

# %%
model = Sequential()
model.add(Embedding(vocab_size, 32, input_length=max_length))
model.add(Dropout(0.2))
model.add(LSTM(32))
model.add(Dropout(0.2))
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 750, 32)           1257280
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 750, 32)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               8448
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 257
# =================================================================
# Total params: 1,274,305
# Trainable params: 1,274,305
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### 1 (f) ii. Report the train and test accuracies of this model.

# %%
# compile network
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit network
model.fit(Xtrain, y_train, batch_size= 10 ,epochs=50)
# Out:
# Epoch 1/50
# 140/140 [==============================] - 51s 349ms/step - loss: 0.6934 - accuracy: 0.5179
# Epoch 2/50
# 140/140 [==============================] - 49s 347ms/step - loss: 0.6818 - accuracy: 0.5443
# Epoch 3/50
# 140/140 [==============================] - 48s 346ms/step - loss: 0.6622 - accuracy: 0.5657
# Epoch 4/50
# 140/140 [==============================] - 48s 346ms/step - loss: 0.6331 - accuracy: 0.5871
# Epoch 5/50
# 140/140 [==============================] - 48s 346ms/step - loss: 0.7908 - accuracy: 0.5350
# Epoch 6/50
# 140/140 [==============================] - 48s 346ms/step - loss: 0.6637 - accuracy: 0.5493
# Epoch 7/50
# 140/140 [==============================] - 48s 346ms/step - loss: 0.6581 - accuracy: 0.5507
# Epoch 8/50
# 140/140 [==============================] - 49s 348ms/step - loss: 0.6331 - accuracy: 0.6129
# Epoch 9/50
# 140/140 [==============================] - 48s 346ms/step - loss: 0.5840 - accuracy: 0.7064
# Epoch 10/50
# 140/140 [==============================] - 38s 270ms/step - loss: 0.4944 - accuracy: 0.6714
# Epoch 11/50
# 140/140 [==============================] - 38s 269ms/step - loss: 0.4900 - accuracy: 0.6607
# Epoch 12/50
# 140/140 [==============================] - 38s 270ms/step - loss: 0.4873 - accuracy: 0.6557
# Epoch 13/50
# 140/140 [==============================] - 38s 270ms/step - loss: 0.4772 - accuracy: 0.6714
# Epoch 14/50
# 140/140 [==============================] - 38s 271ms/step - loss: 0.4898 - accuracy: 0.6586
# Epoch 15/50
# 140/140 [==============================] - 38s 270ms/step - loss: 0.4909 - accuracy: 0.6671
# Epoch 16/50
# 140/140 [==============================] - 73s 524ms/step - loss: 0.4886 - accuracy: 0.6686
# Epoch 17/50
# 140/140 [==============================] - 76s 548ms/step - loss: 0.4850 - accuracy: 0.6864
# Epoch 18/50
# 140/140 [==============================] - 182s 1s/step - loss: 0.4847 - accuracy: 0.6693
# Epoch 19/50
# 140/140 [==============================] - 54s 381ms/step - loss: 0.4799 - accuracy: 0.6714
# Epoch 20/50
# 140/140 [==============================] - 176s 1s/step - loss: 0.4758 - accuracy: 0.6614
# Epoch 21/50
# 140/140 [==============================] - 108s 767ms/step - loss: 0.4695 - accuracy: 0.6814
# Epoch 22/50
# 140/140 [==============================] - 124s 892ms/step - loss: 0.4710 - accuracy: 0.6729
# Epoch 23/50
# 140/140 [==============================] - 161s 1s/step - loss: 0.4936 - accuracy: 0.6736
# Epoch 24/50
# 140/140 [==============================] - 68s 487ms/step - loss: 0.4884 - accuracy: 0.6764
# Epoch 25/50
# 140/140 [==============================] - 183s 1s/step - loss: 0.4874 - accuracy: 0.6807
# Epoch 26/50
# 140/140 [==============================] - 73s 513ms/step - loss: 0.4871 - accuracy: 0.6786
# Epoch 27/50
# 140/140 [==============================] - 157s 1s/step - loss: 0.4859 - accuracy: 0.6743
# Epoch 28/50
# 140/140 [==============================] - 128s 913ms/step - loss: 0.4827 - accuracy: 0.6814
# Epoch 29/50
# 140/140 [==============================] - 103s 739ms/step - loss: 0.4889 - accuracy: 0.6907
# Epoch 30/50
# 140/140 [==============================] - 182s 1s/step - loss: 0.4800 - accuracy: 0.6779
# Epoch 31/50
# 140/140 [==============================] - 47s 328ms/step - loss: 0.4791 - accuracy: 0.6757
# Epoch 32/50
# 140/140 [==============================] - 182s 1s/step - loss: 0.4765 - accuracy: 0.6821
# Epoch 33/50
# 140/140 [==============================] - 95s 677ms/step - loss: 0.4725 - accuracy: 0.6814
# Epoch 34/50
# 140/140 [==============================] - 137s 985ms/step - loss: 0.4604 - accuracy: 0.6907
# Epoch 35/50
# 140/140 [==============================] - 148s 1s/step - loss: 0.4469 - accuracy: 0.7071
# Epoch 36/50
# 140/140 [==============================] - 81s 584ms/step - loss: 0.4502 - accuracy: 0.6986
# Epoch 37/50
# 140/140 [==============================] - 181s 1s/step - loss: 0.4622 - accuracy: 0.6936
# Epoch 38/50
# 140/140 [==============================] - 61s 432ms/step - loss: 0.4738 - accuracy: 0.6850
# Epoch 39/50
# 140/140 [==============================] - 168s 1s/step - loss: 0.4688 - accuracy: 0.6907
# Epoch 40/50
# 140/140 [==============================] - 117s 833ms/step - loss: 0.4610 - accuracy: 0.6986
# Epoch 41/50
# 140/140 [==============================] - 112s 805ms/step - loss: 0.4781 - accuracy: 0.6879
# Epoch 42/50
# 140/140 [==============================] - 173s 1s/step - loss: 0.4609 - accuracy: 0.6957
# Epoch 43/50
# 140/140 [==============================] - 55s 394ms/step - loss: 0.4986 - accuracy: 0.7129
# Epoch 44/50
# 140/140 [==============================] - 180s 1s/step - loss: 0.5037 - accuracy: 0.6750
# Epoch 45/50
# 140/140 [==============================] - 87s 618ms/step - loss: 0.4837 - accuracy: 0.6907
# Epoch 46/50
# 140/140 [==============================] - 140s 1s/step - loss: 0.4594 - accuracy: 0.7136
# Epoch 47/50
# 140/140 [==============================] - 145s 1s/step - loss: 0.4477 - accuracy: 0.7364
# Epoch 48/50
# 140/140 [==============================] - 85s 607ms/step - loss: 0.4344 - accuracy: 0.7436
# Epoch 49/50
# 140/140 [==============================] - 181s 1s/step - loss: 0.4383 - accuracy: 0.7386
# Epoch 50/50
# 140/140 [==============================] - 58s 410ms/step - loss: 0.4348 - accuracy: 0.7293
# <keras.callbacks.History at 0x7fa56aa732b0>

# %%
# evaluate
_, acc = model.evaluate(Xtest, y_test, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 67.500002

# %% [markdown]
# ## References :-
# - <https://datagy.io/python-remove-punctuation-from-string/>
# - <https://stackoverflow.com/questions/12851791/removing-numbers-from-string>
# - <https://stackoverflow.com/questions/18936957/count-distinct-words-from-a-pandas-data-frame>
# - <https://towardsdatascience.com/pandas-concat-tricks-you-should-know-to-speed-up-your-data-analysis-cd3d4fdfe6dd#:~:text=If%20you%20want%20the%20concatenation,%2C%20%E2%80%A6%2C%20n%2D1%20.&text=To%20concatenate%20DataFrames%20horizontally%20along,set%20the%20argument%20axis%3D1%20.>
# - <https://machinelearningmastery.com/predict-sentiment-movie-reviews-using-deep-learning/>
# - <https://machinelearningmastery.com/develop-word-embedding-model-predicting-movie-review-sentiment/>
# - <https://stackabuse.com/python-for-nlp-movie-sentiment-analysis-using-deep-learning-in-keras/>
# - <https://github.com/darshanbagul/LSTM_Sentiment_Classification/blob/master/IMDB_Sentiment_Classification_LSTM.ipynb>
# - <https://keras.io/api/datasets/imdb/>
# - <https://www.kaggle.com/code/faressayah/nlp-sentiment-analysis-with-keras/notebook>
# - <https://medium.com/geekculture/sentiment-analysis-using-rnn-keras-e545fbe000>
# - <https://www.linkedin.com/learning/building-recommender-systems-with-machine-learning-and-ai/sentiment-analysis-of-movie-reviews-using-rnns-and-keras?autoplay=true&u=76870426>
# - <https://machinelearningknowledge.ai/keras-tokenizer-tutorial-with-examples-for-fit_on_texts-texts_to_sequences-texts_to_matrix-sequences_to_matrix/>
# - <https://stackabuse.com/python-for-nlp-word-embeddings-for-deep-learning-in-keras/>
